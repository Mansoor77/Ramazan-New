# %% [markdown]
# **CALCULATIOR**

# %%
def add(x, y):
    """Adds two numbers"""
    return x + y
def subtract(x, y):
    """Subtracts the second number from the first"""
    return x - y
def multiply(x, y):
    """Multiplies two numbers"""
    return x * y

def divide(x, y):
    """Divides the first number by the second"""
    if y != 0:
        return x / y
    else:
        return "Cannot divide by zero"

def power(x, y):
    """Calculates x to the power of y"""
    return x ** y

# Main calculator logic
def calculator():
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Power")

    while True:
        # Take input from the user for the operation choice
        choice = input("Enter choice (1/2/3/4/5): ")

        if choice in ('1', '2', '3', '4', '5'):
            try:
                num1 = float(input("Enter first number: "))
                num2 = float(input("Enter second number: "))
            except ValueError:
                print("Invalid input. Please enter a number.")
                continue
            if choice == '1':
                print(f"{num1} + {num2} = {add(num1, num2)}")
            elif choice == '2':
                print(f"{num1} - {num2} = {subtract(num1, num2)}")
            elif choice == '3':
                print(f"{num1} * {num2} = {multiply(num1, num2)}")
            elif choice == '4':
                result = divide(num1, num2)
                print(f"{num1} / {num2} = {result}")
            elif choice == '5':
                print(f"{num1} ** {num2} = {power(num1, num2)}")
            next_calculation = input("Want to perform another calculation? (yes/no): ")
            if next_calculation.lower() != 'yes':
                break
        else:
            print("Invalid Input. Please enter a valid choice.")
calculator()
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power
# Enter choice (1/2/3/4/5):  1
# Enter first number:  2
# Enter second number:  3
# 2.0 + 3.0 = 5.0
# Want to perform another calculation? (yes/no):  no

# %% [markdown]
# **Numeric value**

# %%
def contains_numeric(data_list):
    for item in data_list:
     
        if isinstance(item, (int, float)):
            return True  
    return False

list_mixed = ["apple", "banana", 123, "cherry", 45.6]


result1 = contains_numeric(list_mixed)

print(f"List 1 contains numeric values: {result1}")
# Out:
# List 1 contains numeric values: True

# %% [markdown]
# **Adding Numeric value**

# %%
my_dict = {'item1': 100, 'item2': 250, 'item3': 15.5}
total_sum = sum(my_dict.values())
print(f"The sum of all numeric values is: {total_sum}")
# Out:
# The sum of all numeric values is: 365.5

# %% [markdown]
# **Duplicate value**

# %%
my_list = [1, 2, 3, 2, 1, 5, 6, 5, 5, 7]
seen = set()
duplicates = set()

for item in my_list:
    if item in seen:
        duplicates.add(item)
    else:
        seen.add(item)

duplicate_list = list(duplicates)
print("Duplicate Values:", duplicate_list)
# Out:
# Duplicate Values: [1, 2, 5]

# %% [markdown]
# **Existing Key**

# %%
my_dict = {'apple': 1, 'banana': 2, 'cherry': 3}
key_to_check = 'banana'
if key_to_check in my_dict:
    print(f"Key '{key_to_check}' exists in the dictionary.")
else:
    print(f"Key '{key_to_check}' does not exist in the dictionary.")
# Out:
# Key 'banana' exists in the dictionary.
