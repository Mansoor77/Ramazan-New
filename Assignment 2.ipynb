# %%
"Length of the list "

per = ["camel", "cow" , "Dog", "Puppy" , "Cat"]

lenght = len(per)
print(lenght)
# Out:
# 5

# %%
"Sum of list"

abc = [1,2,3,4,5,6,7]

addition = sum(abc)
print (addition)
# Out:
# 28

# %%
"large number"
abc = [1,2,3,4,5,6,7]

large = max(abc)
print(large)
# Out:
# 7

# %%
"less than 5"

abc = [1,1,3,5,8,13,21,34,55,89]
new_list = []

for i in abc:
    if i < 5:
        new_list.append(i)
print(new_list)
# Out:
# [1, 1, 3]
